# %% [markdown]
# MU Combinatorics - Poker

# %%
import standardDeck
import analytics as ana
import poker as pkr

# %%
DECK = standardDeck.generate_deck()

# %%
testHand = pkr.draw_N(DECK, 5)
testHand
# Out:
# [3.75, 4.75, 10.5, 12.5, 13.5]

# %%
testHand = pkr.seek_handtype(DECK, 5, pkr.has_pair)
testHand
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 testHand = pkr.seek_handtype(DECK, 5, pkr.has_pair)
#       2 testHand
#
# AttributeError: module 'poker' has no attribute 'seek_handtype'
