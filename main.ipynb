# %% [markdown]
# MU Combinatorics - Poker

# %%
import standardDeck
import analytics as ana
import poker as pkr

# %%
DECK = standardDeck.generate_deck()

# %%
pokeerCombn = ana.get_combinations(DECK, 5)
# Out:
# 2598960

# %%
testHand = pkr.seek_handtype(DECK, pkr.is_royalflush, 5)
testHand
# Out:
# [10.5, 11.5, 12.5, 13.5, 14.5]
