# %% [markdown]
# MU Combinatorics - Poker

# %%
import standardDeck
import analytics as ana
import poker as pkr

# %%
DECK = standardDeck.generate_deck()

# %%
ana.get_combinations(DECK, 2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 ana.get_combinations(DECK, 2)
#
# AttributeError: module 'analytics' has no attribute 'get_combinations'

# %%
testHand = pkr.seek_handtype(DECK, pkr.is_royalflush, 5)
testHand
# Out:
# [10.5, 11.5, 12.5, 13.5, 14.5]
