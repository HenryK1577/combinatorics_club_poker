# %% [markdown]
# MU Combinatorics - Poker

# %%
import standardDeck
import analytics as ana
import poker as pkr

# %%
DECK = standardDeck.generate_deck()

# %%
testHand = pkr.draw_N(DECK, 5)
testHand
# Out:
# [4.25, 5.25, 11.75, 12.75, 13.75]

# %%
ana.nCr(52, 2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 ana.nCr(52, 2)
#
# AttributeError: module 'analytics' has no attribute 'nCr'
