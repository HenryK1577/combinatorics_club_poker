# %% [markdown]
# MU Combinatorics - Poker

# %%
import standardDeck
import analytics as ana
import poker as pkr

# %%
DECK = standardDeck.generate_deck()

# %%
pokerCombn = ana.get_combinations(DECK, 5)
pokerCombn = [list(x) for x in pokerCombn]

# %%
pkr.analyze_hands(pokerCombn)

#            HC        P        2P      3K     ST     FL    FH    4K   SF  RF
#Should be - [1302540, 1098240, 123552, 54912, 10200, 5108, 3744, 624, 36, 4]
# Last test- [1303560, 1117248, 104544, 55536, 9180, 5112, 3744, 0, 32, 4]
# Out:
# [1303560, 1117248, 104544, 55536, 9180, 5112, 3744, 0, 32, 4]
