# %% [markdown]
# MU Combinatorics - Poker

# %%
import standardDeck
import analytics as ana
import poker as pkr

# %%
DECK = standardDeck.generate_deck()

# %%
testHand = pkr.draw_N(DECK, 5)
testHand
# Out:
# [4.0, 7.75, 10.75, 12.25, 12.5]

# %%
testHand = pkr.seek_handtype(DECK, pkr.has_pair, 5)
testHand
# Out:
# [4.0, 4.5, 8.25, 9.5, 14.25]
